# %% [markdown]
# # MotorHandPro Hardware Integration
#
# **Topics:**
# - Hardware bridge setup
# - Serial communication protocol
# - Real-time control
# - Performance benchmarking
#
# ---
#
# ## 1. Hardware Bridge Overview

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

from primal_logic import MotorHandProBridge
import numpy as np

if MotorHandProBridge is None:
    print('⚠️  NumPy required for MotorHandPro integration')
    print('Install: pip install numpy')
else:
    print('✅ MotorHandPro bridge available!')
    print('Hardware integration ready')

# %% [markdown]
# ## 2. Serial Communication
#
# ```python
# # Connect to hardware
# bridge = MotorHandProBridge(port='/dev/ttyACM0', baud=115200)
#
# # Send commands
# bridge.send_positions([0.5, 0.7, 0.9])
#
# # Read feedback
# angles = bridge.read_angles()
# ```
#
# See `external/MotorHandPro/README.md` for full hardware setup.
